# %% [markdown]
# ## Sending requests
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")

# %%
resp_json = response.json()

# %%
resp_json
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(resp_json)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
requests.get("https://api.github.com/zen").text
# Out:
# 'Encourage flow.'

# %%
response = requests.get('https://api.github.com/events')

# %%
# get the .json from the response

github_response = response.json()

# %%
github_response
# Out:
# [{'id': '19013489308',
#   'type': 'PushEvent',
#   'actor': {'id': 94531811,
#    'login': 'Sakura202119',
#    'display_login': 'Sakura202119',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Sakura202119',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94531811?'},
#   'repo': {'id': 429014024,
#    'name': 'Sakura202119/Sakura202119.githup.io',
#    'url': 'https://api.github.com/repos/Sakura202119/Sakura202119.githup.io'},
#   'payload': {'push_id': 8452775958,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '51700ab8d053b4c14a5526722f95dab219c1956a',
#    'before': '0ea9e9004a3b8dfc9c056005d7c2baef2bd1b2ba',
#    'commits': [{'sha': '51700ab8d053b4c14a5526722f95dab219c1956a',
#      'author': {'email': '94531811+Sakura202119@users.noreply.github.com',
#       'name': 'Sakura202119'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Sakura202119/Sakura202119.githup.io/commits/51700ab8d053b4c14a5526722f95dab219c1956a'}]},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z'},
#  {'id': '19013489311',
#   'type': 'PushEvent',
#   'actor': {'id': 58818501,
#    'login': 'beau1004',
#    'display_login': 'beau1004',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beau1004',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58818501?'},
#   'repo': {'id': 227630020,
#    'name': 'beau1004/-db',
#    'url': 'https://api.github.com/repos/beau1004/-db'},
#   'payload': {'push_id': 8452775975,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2852538540321c40850f33dcab6a05b7de5e9573',
#    'before': '59f3421d62f48db0ab5bd13da3954e7bf89cb1ad',
#    'commits': [{'sha': '2852538540321c40850f33dcab6a05b7de5e9573',
#      'author': {'email': '58818501+beau1004@users.noreply.github.com',
#       'name': 'beau1004'},
#      'message': 'bossDB',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/beau1004/-db/commits/2852538540321c40850f33dcab6a05b7de5e9573'}]},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z'},
#  {'id': '19013489331',
#   'type': 'PushEvent',
#   'actor': {'id': 78013523,
#    'login': 'hunojung',
#    'display_login': 'hunojung',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hunojung',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78013523?'},
#   'repo': {'id': 407233466,
#    'name': 'hunojung/hunojung.github.io',
#    'url': 'https://api.github.com/repos/hunojung/hunojung.github.io'},
#   'payload': {'push_id': 8452775978,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8fd395ef8f7fe810b006bc49653a559f8acfbf95',
#    'before': '3226bf6d2f6f452b46498910c4b725d3eeb59fff',
#    'commits': [{'sha': '8fd395ef8f7fe810b006bc49653a559f8acfbf95',
#      'author': {'email': 'huno0504@naver.com', 'name': 'hunojung'},
#      'message': 'EDIT category',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hunojung/hunojung.github.io/commits/8fd395ef8f7fe810b006bc49653a559f8acfbf95'}]},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z'},
#  {'id': '19013489333',
#   'type': 'PushEvent',
#   'actor': {'id': 58818501,
#    'login': 'beau1004',
#    'display_login': 'beau1004',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beau1004',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58818501?'},
#   'repo': {'id': 227630020,
#    'name': 'beau1004/-db',
#    'url': 'https://api.github.com/repos/beau1004/-db'},
#   'payload': {'push_id': 8452775964,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8eeb9d5805a064a37c2304d98b5c56a9225d8b1b',
#    'before': '2852538540321c40850f33dcab6a05b7de5e9573',
#    'commits': [{'sha': '8eeb9d5805a064a37c2304d98b5c56a9225d8b1b',
#      'author': {'email': '58818501+beau1004@users.noreply.github.com',
#       'name': 'beau1004'},
#      'message': 'updated kill_list.ini',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/beau1004/-db/commits/8eeb9d5805a064a37c2304d98b5c56a9225d8b1b'}]},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z'},
#  {'id': '19013489330',
#   'type': 'CreateEvent',
#   'actor': {'id': 53108186,
#    'login': 'codestar-github-bot-1',
#    'display_login': 'codestar-github-bot-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-github-bot-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108186?'},
#   'repo': {'id': 431082214,
#    'name': 'codestar-github-bot-1/user-public-seeded-repo-ap-southeast-1',
#    'url': 'https://api.github.com/repos/codestar-github-bot-1/user-public-seeded-repo-ap-southeast-1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Seeded Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z'},
#  {'id': '19013489301',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 13945069,
#    'login': 'jon-shipley',
#    'display_login': 'jon-shipley',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jon-shipley',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13945069?'},
#   'repo': {'id': 79137062,
#    'name': 'DFEAGILEDEVOPS/MTC',
#    'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC'},
#   'payload': {'action': 'created',
#    'review': {'id': 813562044,
#     'node_id': 'PRR_kwDOBLeJJs4wffi8',
#     'user': {'login': 'jon-shipley',
#      'id': 13945069,
#      'node_id': 'MDQ6VXNlcjEzOTQ1MDY5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/13945069?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jon-shipley',
#      'html_url': 'https://github.com/jon-shipley',
#      'followers_url': 'https://api.github.com/users/jon-shipley/followers',
#      'following_url': 'https://api.github.com/users/jon-shipley/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jon-shipley/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jon-shipley/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jon-shipley/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jon-shipley/orgs',
#      'repos_url': 'https://api.github.com/users/jon-shipley/repos',
#      'events_url': 'https://api.github.com/users/jon-shipley/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jon-shipley/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'lgtm',
#     'commit_id': 'd92348d41c5785a83088f500a7baaa3ba4cfa44c',
#     'submitted_at': '2021-11-23T11:56:28Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/DFEAGILEDEVOPS/MTC/pull/2039#pullrequestreview-813562044',
#     'pull_request_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039',
#     'author_association': 'COLLABORATOR',
#     '_links': {'html': {'href': 'https://github.com/DFEAGILEDEVOPS/MTC/pull/2039#pullrequestreview-813562044'},
#      'pull_request': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039',
#     'id': 786399981,
#     'node_id': 'PR_kwDOBLeJJs4u34Lt',
#     'html_url': 'https://github.com/DFEAGILEDEVOPS/MTC/pull/2039',
#     'diff_url': 'https://github.com/DFEAGILEDEVOPS/MTC/pull/2039.diff',
#     'patch_url': 'https://github.com/DFEAGILEDEVOPS/MTC/pull/2039.patch',
#     'issue_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/2039',
#     'number': 2039,
#     'state': 'open',
#     'locked': False,
#     'title': 'Webdrivers Security roll up',
#     'user': {'login': 'activemq',
#      'id': 7300442,
#      'node_id': 'MDQ6VXNlcjczMDA0NDI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/7300442?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/activemq',
#      'html_url': 'https://github.com/activemq',
#      'followers_url': 'https://api.github.com/users/activemq/followers',
#      'following_url': 'https://api.github.com/users/activemq/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/activemq/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/activemq/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/activemq/subscriptions',
#      'organizations_url': 'https://api.github.com/users/activemq/orgs',
#      'repos_url': 'https://api.github.com/users/activemq/repos',
#      'events_url': 'https://api.github.com/users/activemq/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/activemq/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2021-11-22T20:32:54Z',
#     'updated_at': '2021-11-23T11:56:28Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '4dab7f19c9226a6d35ad617ada04089389abbe18',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 724620886,
#       'node_id': 'MDU6TGFiZWw3MjQ2MjA4ODY=',
#       'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/labels/Tested',
#       'name': 'Tested',
#       'color': '0e8a16',
#       'default': False,
#       'description': None},
#      {'id': 745390762,
#       'node_id': 'MDU6TGFiZWw3NDUzOTA3NjI=',
#       'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/labels/Ready%20to%20merge',
#       'name': 'Ready to merge',
#       'color': '48ce48',
#       'default': False,
#       'description': None},
#      {'id': 861719997,
#       'node_id': 'MDU6TGFiZWw4NjE3MTk5OTc=',
#       'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/labels/CI%20Enabled',
#       'name': 'CI Enabled',
#       'color': 'f4138b',
#       'default': False,
#       'description': 'Travis will only build PRs with this label assigned'},
#      {'id': 1373932643,
#       'node_id': 'MDU6TGFiZWwxMzczOTMyNjQz',
#       'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/labels/ruby',
#       'name': 'ruby',
#       'color': 'ce2d2d',
#       'default': False,
#       'description': 'Pull requests that update Ruby code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039/commits',
#     'review_comments_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039/comments',
#     'review_comment_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/2039/comments',
#     'statuses_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/statuses/d92348d41c5785a83088f500a7baaa3ba4cfa44c',
#     'head': {'label': 'DFEAGILEDEVOPS:feature/snyk-security-updates',
#      'ref': 'feature/snyk-security-updates',
#      'sha': 'd92348d41c5785a83088f500a7baaa3ba4cfa44c',
#      'user': {'login': 'DFEAGILEDEVOPS',
#       'id': 11753480,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNzUzNDgw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/11753480?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DFEAGILEDEVOPS',
#       'html_url': 'https://github.com/DFEAGILEDEVOPS',
#       'followers_url': 'https://api.github.com/users/DFEAGILEDEVOPS/followers',
#       'following_url': 'https://api.github.com/users/DFEAGILEDEVOPS/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DFEAGILEDEVOPS/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DFEAGILEDEVOPS/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DFEAGILEDEVOPS/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DFEAGILEDEVOPS/orgs',
#       'repos_url': 'https://api.github.com/users/DFEAGILEDEVOPS/repos',
#       'events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 79137062,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3OTEzNzA2Mg==',
#       'name': 'MTC',
#       'full_name': 'DFEAGILEDEVOPS/MTC',
#       'private': False,
#       'owner': {'login': 'DFEAGILEDEVOPS',
#        'id': 11753480,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNzUzNDgw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/11753480?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/DFEAGILEDEVOPS',
#        'html_url': 'https://github.com/DFEAGILEDEVOPS',
#        'followers_url': 'https://api.github.com/users/DFEAGILEDEVOPS/followers',
#        'following_url': 'https://api.github.com/users/DFEAGILEDEVOPS/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/DFEAGILEDEVOPS/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/DFEAGILEDEVOPS/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/DFEAGILEDEVOPS/subscriptions',
#        'organizations_url': 'https://api.github.com/users/DFEAGILEDEVOPS/orgs',
#        'repos_url': 'https://api.github.com/users/DFEAGILEDEVOPS/repos',
#        'events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/DFEAGILEDEVOPS/MTC',
#       'description': 'Multiplication Tables',
#       'fork': False,
#       'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC',
#       'forks_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/forks',
#       'keys_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/teams',
#       'hooks_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/hooks',
#       'issue_events_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/events',
#       'assignees_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/tags',
#       'blobs_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/languages',
#       'stargazers_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/stargazers',
#       'contributors_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/contributors',
#       'subscribers_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/subscribers',
#       'subscription_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/subscription',
#       'commits_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/merges',
#       'archive_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/downloads',
#       'issues_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/deployments',
#       'created_at': '2017-01-16T16:30:20Z',
#       'updated_at': '2021-11-23T09:16:33Z',
#       'pushed_at': '2021-11-23T11:46:32Z',
#       'git_url': 'git://github.com/DFEAGILEDEVOPS/MTC.git',
#       'ssh_url': 'git@github.com:DFEAGILEDEVOPS/MTC.git',
#       'clone_url': 'https://github.com/DFEAGILEDEVOPS/MTC.git',
#       'svn_url': 'https://github.com/DFEAGILEDEVOPS/MTC',
#       'homepage': None,
#       'size': 57858,
#       'stargazers_count': 9,
#       'watchers_count': 9,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 14,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 14,
#       'open_issues': 6,
#       'watchers': 9,
#       'default_branch': 'master'}},
#     'base': {'label': 'DFEAGILEDEVOPS:master',
#      'ref': 'master',
#      'sha': '998c6c66e61d49c4656900f688e293d1f11cb6af',
#      'user': {'login': 'DFEAGILEDEVOPS',
#       'id': 11753480,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNzUzNDgw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/11753480?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DFEAGILEDEVOPS',
#       'html_url': 'https://github.com/DFEAGILEDEVOPS',
#       'followers_url': 'https://api.github.com/users/DFEAGILEDEVOPS/followers',
#       'following_url': 'https://api.github.com/users/DFEAGILEDEVOPS/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DFEAGILEDEVOPS/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DFEAGILEDEVOPS/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DFEAGILEDEVOPS/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DFEAGILEDEVOPS/orgs',
#       'repos_url': 'https://api.github.com/users/DFEAGILEDEVOPS/repos',
#       'events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 79137062,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3OTEzNzA2Mg==',
#       'name': 'MTC',
#       'full_name': 'DFEAGILEDEVOPS/MTC',
#       'private': False,
#       'owner': {'login': 'DFEAGILEDEVOPS',
#        'id': 11753480,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNzUzNDgw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/11753480?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/DFEAGILEDEVOPS',
#        'html_url': 'https://github.com/DFEAGILEDEVOPS',
#        'followers_url': 'https://api.github.com/users/DFEAGILEDEVOPS/followers',
#        'following_url': 'https://api.github.com/users/DFEAGILEDEVOPS/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/DFEAGILEDEVOPS/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/DFEAGILEDEVOPS/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/DFEAGILEDEVOPS/subscriptions',
#        'organizations_url': 'https://api.github.com/users/DFEAGILEDEVOPS/orgs',
#        'repos_url': 'https://api.github.com/users/DFEAGILEDEVOPS/repos',
#        'events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/DFEAGILEDEVOPS/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/DFEAGILEDEVOPS/MTC',
#       'description': 'Multiplication Tables',
#       'fork': False,
#       'url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC',
#       'forks_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/forks',
#       'keys_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/teams',
#       'hooks_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/hooks',
#       'issue_events_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/events',
#       'assignees_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/tags',
#       'blobs_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/languages',
#       'stargazers_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/stargazers',
#       'contributors_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/contributors',
#       'subscribers_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/subscribers',
#       'subscription_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/subscription',
#       'commits_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/merges',
#       'archive_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/downloads',
#       'issues_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/deployments',
#       'created_at': '2017-01-16T16:30:20Z',
#       'updated_at': '2021-11-23T09:16:33Z',
#       'pushed_at': '2021-11-23T11:46:32Z',
#       'git_url': 'git://github.com/DFEAGILEDEVOPS/MTC.git',
#       'ssh_url': 'git@github.com:DFEAGILEDEVOPS/MTC.git',
#       'clone_url': 'https://github.com/DFEAGILEDEVOPS/MTC.git',
#       'svn_url': 'https://github.com/DFEAGILEDEVOPS/MTC',
#       'homepage': None,
#       'size': 57858,
#       'stargazers_count': 9,
#       'watchers_count': 9,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 14,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 14,
#       'open_issues': 6,
#       'watchers': 9,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039'},
#      'html': {'href': 'https://github.com/DFEAGILEDEVOPS/MTC/pull/2039'},
#      'issue': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/2039'},
#      'comments': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/issues/2039/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/pulls/2039/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/DFEAGILEDEVOPS/MTC/statuses/d92348d41c5785a83088f500a7baaa3ba4cfa44c'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z',
#   'org': {'id': 11753480,
#    'login': 'DFEAGILEDEVOPS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DFEAGILEDEVOPS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11753480?'}},
#  {'id': '19013489244',
#   'type': 'PushEvent',
#   'actor': {'id': 64685513,
#    'login': 'arunava-webdev4u',
#    'display_login': 'arunava-webdev4u',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arunava-webdev4u',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64685513?'},
#   'repo': {'id': 366593524,
#    'name': 'arunava-webdev4u/Projects',
#    'url': 'https://api.github.com/repos/arunava-webdev4u/Projects'},
#   'payload': {'push_id': 8452775876,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '81a7e18ccc7e847dcb3ca5dcfcfee84068240335',
#    'before': 'a31346bc096e22ad1df2ccdb5b37b1237ab205db',
#    'commits': [{'sha': 'd967dc8e596fe111dbd48cd6a46bf723550543c5',
#      'author': {'email': 'arunava52486@gmail.com', 'name': 'arunava-webdev4u'},
#      'message': 'Project setup done',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/arunava-webdev4u/Projects/commits/d967dc8e596fe111dbd48cd6a46bf723550543c5'},
#     {'sha': '81a7e18ccc7e847dcb3ca5dcfcfee84068240335',
#      'author': {'email': 'arunava52486@gmail.com', 'name': 'arunava-webdev4u'},
#      'message': 'v2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/arunava-webdev4u/Projects/commits/81a7e18ccc7e847dcb3ca5dcfcfee84068240335'}]},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z'},
#  {'id': '19013489258',
#   'type': 'PushEvent',
#   'actor': {'id': 28655608,
#    'login': 'Rodriguesss',
#    'display_login': 'Rodriguesss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rodriguesss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28655608?'},
#   'repo': {'id': 428865170,
#    'name': 'Douglas-CRVG/Driven-BuzzQuizz',
#    'url': 'https://api.github.com/repos/Douglas-CRVG/Driven-BuzzQuizz'},
#   'payload': {'push_id': 8452775923,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2fca7080dafca643e371420db0e686a088eacd19',
#    'before': '0ac58e4f0a5dd1d79466914b36d3c40f4f99b48b',
#    'commits': [{'sha': 'add9b3d26768c471208675d67a3b06bbddfca29e',
#      'author': {'email': 'douglas.07.nascimento@gmail.com', 'name': 'Douglas'},
#      'message': 'Quiz levels',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Douglas-CRVG/Driven-BuzzQuizz/commits/add9b3d26768c471208675d67a3b06bbddfca29e'},
#     {'sha': '2fca7080dafca643e371420db0e686a088eacd19',
#      'author': {'email': 'viniciusrdefreitas@gmail.com', 'name': 'Vinícius'},
#      'message': 'Merge pull request #8 from Douglas-CRVG/create-levels\n\nQuiz levels',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Douglas-CRVG/Driven-BuzzQuizz/commits/2fca7080dafca643e371420db0e686a088eacd19'}]},
#   'public': True,
#   'created_at': '2021-11-23T11:56:28Z'},
#  {'id': '19013489237',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 11741250,
#    'login': 'stockiNail',
#    'display_login': 'stockiNail',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stockiNail',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11741250?'},
#   'repo': {'id': 58691635,
#    'name': 'chartjs/chartjs-plugin-annotation',
#    'url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation'},
#   'payload': {'action': 'opened',
#    'number': 503,
#    'pull_request': {'url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/pulls/503',
#     'id': 786901750,
#     'node_id': 'PR_kwDOA3-QM84u5yr2',
#     'html_url': 'https://github.com/chartjs/chartjs-plugin-annotation/pull/503',
#     'diff_url': 'https://github.com/chartjs/chartjs-plugin-annotation/pull/503.diff',
#     'patch_url': 'https://github.com/chartjs/chartjs-plugin-annotation/pull/503.patch',
#     'issue_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/issues/503',
#     'number': 503,
#     'state': 'open',
#     'locked': False,
#     'title': 'Add POLYGON annotation',
#     'user': {'login': 'stockiNail',
#      'id': 11741250,
#      'node_id': 'MDQ6VXNlcjExNzQxMjUw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/11741250?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/stockiNail',
#      'html_url': 'https://github.com/stockiNail',
#      'followers_url': 'https://api.github.com/users/stockiNail/followers',
#      'following_url': 'https://api.github.com/users/stockiNail/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/stockiNail/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/stockiNail/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/stockiNail/subscriptions',
#      'organizations_url': 'https://api.github.com/users/stockiNail/orgs',
#      'repos_url': 'https://api.github.com/users/stockiNail/repos',
#      'events_url': 'https://api.github.com/users/stockiNail/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/stockiNail/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Fixes #431\r\n\r\nCreates new `PolygonAnnotation` element to enable to render whatever polygin on the chart at a coordinate, calculated by the chart data values.\r\n\r\n![poligon](https://user-images.githubusercontent.com/11741250/143019897-cf5376f3-ca7c-45ac-b569-88a687ec4618.png)\r\n\r\n### TODO\r\n\r\n- [ ] must be updated in order to reuse common code of #502 \r\n- [ ] test cases\r\n- [ ] types definition\r\n- [ ] documentation',
#     'created_at': '2021-11-23T11:56:27Z',
#     'updated_at': '2021-11-23T11:56:27Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': True,
#     'commits_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/pulls/503/commits',
#     'review_comments_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/pulls/503/comments',
#     'review_comment_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/issues/503/comments',
#     'statuses_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/statuses/667910029e88e2785946fcc4af5c45cc212b2f65',
#     'head': {'label': 'pepstock-org:polygonAnnotation',
#      'ref': 'polygonAnnotation',
#      'sha': '667910029e88e2785946fcc4af5c45cc212b2f65',
#      'user': {'login': 'pepstock-org',
#       'id': 11522533,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNTIyNTMz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/11522533?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/pepstock-org',
#       'html_url': 'https://github.com/pepstock-org',
#       'followers_url': 'https://api.github.com/users/pepstock-org/followers',
#       'following_url': 'https://api.github.com/users/pepstock-org/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/pepstock-org/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/pepstock-org/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/pepstock-org/subscriptions',
#       'organizations_url': 'https://api.github.com/users/pepstock-org/orgs',
#       'repos_url': 'https://api.github.com/users/pepstock-org/repos',
#       'events_url': 'https://api.github.com/users/pepstock-org/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/pepstock-org/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 308561884,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMDg1NjE4ODQ=',
#       'name': 'chartjs-plugin-annotation',
#       'full_name': 'pepstock-org/chartjs-plugin-annotation',
#       'private': False,
#       'owner': {'login': 'pepstock-org',
#        'id': 11522533,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNTIyNTMz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/11522533?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pepstock-org',
#        'html_url': 'https://github.com/pepstock-org',
#        'followers_url': 'https://api.github.com/users/pepstock-org/followers',
#        'following_url': 'https://api.github.com/users/pepstock-org/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pepstock-org/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pepstock-org/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pepstock-org/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pepstock-org/orgs',
#        'repos_url': 'https://api.github.com/users/pepstock-org/repos',
#        'events_url': 'https://api.github.com/users/pepstock-org/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pepstock-org/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/pepstock-org/chartjs-plugin-annotation',
#       'description': 'Annotation plugin for Chart.js',
#       'fork': True,
#       'url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation',
#       'forks_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/forks',
#       'keys_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/teams',
#       'hooks_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/events',
#       'assignees_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/tags',
#       'blobs_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/languages',
#       'stargazers_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/subscription',
#       'commits_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/merges',
#       'archive_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/downloads',
#       'issues_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pepstock-org/chartjs-plugin-annotation/deployments',
#       'created_at': '2020-10-30T07:56:52Z',
#       'updated_at': '2021-11-18T12:23:05Z',
#       'pushed_at': '2021-11-23T11:51:53Z',
#       'git_url': 'git://github.com/pepstock-org/chartjs-plugin-annotation.git',
#       'ssh_url': 'git@github.com:pepstock-org/chartjs-plugin-annotation.git',
#       'clone_url': 'https://github.com/pepstock-org/chartjs-plugin-annotation.git',
#       'svn_url': 'https://github.com/pepstock-org/chartjs-plugin-annotation',
#       'homepage': None,
#       'size': 4510,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'chartjs:master',
#      'ref': 'master',
#      'sha': '6e1fe29f00adb623a5c8c1d3f80be4d50c3f729c',
#      'user': {'login': 'chartjs',
#       'id': 10342521,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEwMzQyNTIx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/10342521?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chartjs',
#       'html_url': 'https://github.com/chartjs',
#       'followers_url': 'https://api.github.com/users/chartjs/followers',
#       'following_url': 'https://api.github.com/users/chartjs/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chartjs/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chartjs/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chartjs/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chartjs/orgs',
#       'repos_url': 'https://api.github.com/users/chartjs/repos',
#       'events_url': 'https://api.github.com/users/chartjs/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chartjs/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 58691635,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk1ODY5MTYzNQ==',
#       'name': 'chartjs-plugin-annotation',
#       'full_name': 'chartjs/chartjs-plugin-annotation',
#       'private': False,
#       'owner': {'login': 'chartjs',
#        'id': 10342521,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEwMzQyNTIx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/10342521?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/chartjs',
#        'html_url': 'https://github.com/chartjs',
#        'followers_url': 'https://api.github.com/users/chartjs/followers',
#        'following_url': 'https://api.github.com/users/chartjs/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/chartjs/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/chartjs/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/chartjs/subscriptions',
#        'organizations_url': 'https://api.github.com/users/chartjs/orgs',
#        'repos_url': 'https://api.github.com/users/chartjs/repos',
#        'events_url': 'https://api.github.com/users/chartjs/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/chartjs/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/chartjs/chartjs-plugin-annotation',
#       'description': 'Annotation plugin for Chart.js',
#       'fork': False,
#       'url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation',
#       'forks_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/forks',
#       'keys_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/teams',
#       'hooks_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/hooks',
#       'issue_events_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/events',
#       'assignees_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/tags',
#       'blobs_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/languages',
#       'stargazers_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/stargazers',
#       'contributors_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/contributors',
#       'subscribers_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/subscribers',
#       'subscription_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/subscription',
#       'commits_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/merges',
#       'archive_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/downloads',
#       'issues_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/chartjs/chartjs-plugin-annotation/deployments',
#       'created_at': '2016-05-13T02:11:19Z',
#       'updated_at': '2021-11-18T11:44:09Z',
#       'pushed_at': '2021-11-23T11:56:28Z',
#       'git_url': 'git://github.com/chartjs/chartjs-plugin-annotation.git',
#       'ssh_url': 'git@github.com:chartjs/chartjs-plugin-annotation.git',
#       'clone_url': 'https://github.com/chartjs/chartjs-plugin-annotation.git',
#       'svn_url': 'https://github.com/chartjs/chartjs-plugin-annotation',
#       'homepage': None,
#       'size': 10441,
#       'stargazers_count': 436,
#       'watchers_count': 436,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': True,
#       'forks_count': 240,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 13,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['annotation', 'chartjs', 'plugin'],
#       'visibility': 'public',
#       'forks': 240,
#       'open_issues': 13,
# ...
#      'events_url': 'https://api.github.com/users/jasonwilliams/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jasonwilliams/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-11-23T11:56:27Z',
#     'updated_at': '2021-11-23T11:56:27Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Looks like the examples still target ES6 for the code output.\r\nI can understand this for older browsers but VSCode doesn’t need this. As of v1.60 (and probably older) ES2020 can be used, this means a lot of boilerplate and polyfills don’t need to be generated reducing the final output.\r\n\r\nIt would be useful to update the examples to use a more up to date version of JavaScript.',
#     'reactions': {'url': 'https://api.github.com/repos/microsoft/vscode-extension-samples/issues/530/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/microsoft/vscode-extension-samples/issues/530/timeline',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T11:56:27Z',
#   'org': {'id': 6154722,
#    'login': 'microsoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/microsoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6154722?'}},
#  {'id': '19013489089',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 90478568,
#    'login': 'OnkelDok',
#    'display_login': 'OnkelDok',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OnkelDok',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90478568?'},
#   'repo': {'id': 3816238,
#    'name': 'buchen/portfolio',
#    'url': 'https://api.github.com/repos/buchen/portfolio'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/buchen/portfolio/issues/2546',
#     'repository_url': 'https://api.github.com/repos/buchen/portfolio',
#     'labels_url': 'https://api.github.com/repos/buchen/portfolio/issues/2546/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/buchen/portfolio/issues/2546/comments',
#     'events_url': 'https://api.github.com/repos/buchen/portfolio/issues/2546/events',
#     'html_url': 'https://github.com/buchen/portfolio/issues/2546',
#     'id': 1060627883,
#     'node_id': 'I_kwDOADo7Ls4_N-Wr',
#     'number': 2546,
#     'title': 'Changing filters resets widgets',
#     'user': {'login': 'funnym0nk3y',
#      'id': 41870754,
#      'node_id': 'MDQ6VXNlcjQxODcwNzU0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/41870754?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/funnym0nk3y',
#      'html_url': 'https://github.com/funnym0nk3y',
#      'followers_url': 'https://api.github.com/users/funnym0nk3y/followers',
#      'following_url': 'https://api.github.com/users/funnym0nk3y/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/funnym0nk3y/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/funnym0nk3y/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/funnym0nk3y/subscriptions',
#      'organizations_url': 'https://api.github.com/users/funnym0nk3y/orgs',
#      'repos_url': 'https://api.github.com/users/funnym0nk3y/repos',
#      'events_url': 'https://api.github.com/users/funnym0nk3y/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/funnym0nk3y/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1922289,
#       'node_id': 'MDU6TGFiZWwxOTIyMjg5',
#       'url': 'https://api.github.com/repos/buchen/portfolio/labels/bug',
#       'name': 'bug',
#       'color': 'fc2929',
#       'default': True,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2021-11-22T21:53:07Z',
#     'updated_at': '2021-11-23T11:56:27Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '**Describe the bug**\r\nChanging filters to include or exclude accounts resets the data source to include all. \r\nMore specific: I made a selection of some accounts and created a new data source/filter named "selection" . Changing the accounts in this data source leads to the following behaviour: The widget in the performance overview still displays "selection" as data source but displays values from all accounts. \r\n\r\n\r\n**Desktop (please complete the following information):**\r\n - OS: Windows\r\n - Version: 0.56.0\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/buchen/portfolio/issues/2546/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/buchen/portfolio/issues/2546/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/buchen/portfolio/issues/comments/976441433',
#     'html_url': 'https://github.com/buchen/portfolio/issues/2546#issuecomment-976441433',
#     'issue_url': 'https://api.github.com/repos/buchen/portfolio/issues/2546',
#     'id': 976441433,
#     'node_id': 'IC_kwDOADo7Ls46M1BZ',
#     'user': {'login': 'OnkelDok',
#      'id': 90478568,
#      'node_id': 'MDQ6VXNlcjkwNDc4NTY4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/90478568?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/OnkelDok',
#      'html_url': 'https://github.com/OnkelDok',
#      'followers_url': 'https://api.github.com/users/OnkelDok/followers',
#      'following_url': 'https://api.github.com/users/OnkelDok/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/OnkelDok/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/OnkelDok/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/OnkelDok/subscriptions',
#      'organizations_url': 'https://api.github.com/users/OnkelDok/orgs',
#      'repos_url': 'https://api.github.com/users/OnkelDok/repos',
#      'events_url': 'https://api.github.com/users/OnkelDok/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/OnkelDok/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-11-23T11:56:27Z',
#     'updated_at': '2021-11-23T11:56:27Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Thank you for the gif. In your gif you also see the issue I captured in my video. Ok I understand this and I will try to find the reason for this update issue.',
#     'reactions': {'url': 'https://api.github.com/repos/buchen/portfolio/issues/comments/976441433/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T11:56:27Z'},
#  {'id': '19013489082',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 3110813,
#    'login': 'krzema12',
#    'display_login': 'krzema12',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krzema12',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3110813?'},
#   'repo': {'id': 312049057,
#    'name': 'krzema12/kotlin-python',
#    'url': 'https://api.github.com/repos/krzema12/kotlin-python'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/51',
#     'repository_url': 'https://api.github.com/repos/krzema12/kotlin-python',
#     'labels_url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/51/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/51/comments',
#     'events_url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/51/events',
#     'html_url': 'https://github.com/krzema12/kotlin-python/issues/51',
#     'id': 1059474477,
#     'node_id': 'I_kwDOEpl9oc4_Jkwt',
#     'number': 51,
#     'title': 'Assess support for MicroPython',
#     'user': {'login': 'krzema12',
#      'id': 3110813,
#      'node_id': 'MDQ6VXNlcjMxMTA4MTM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3110813?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/krzema12',
#      'html_url': 'https://github.com/krzema12',
#      'followers_url': 'https://api.github.com/users/krzema12/followers',
#      'following_url': 'https://api.github.com/users/krzema12/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/krzema12/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/krzema12/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/krzema12/subscriptions',
#      'organizations_url': 'https://api.github.com/users/krzema12/orgs',
#      'repos_url': 'https://api.github.com/users/krzema12/repos',
#      'events_url': 'https://api.github.com/users/krzema12/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/krzema12/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2498246328,
#       'node_id': 'MDU6TGFiZWwyNDk4MjQ2MzI4',
#       'url': 'https://api.github.com/repos/krzema12/kotlin-python/labels/enhancement',
#       'name': 'enhancement',
#       'color': 'a2eeef',
#       'default': True,
#       'description': 'New feature or request'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'krzema12',
#      'id': 3110813,
#      'node_id': 'MDQ6VXNlcjMxMTA4MTM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3110813?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/krzema12',
#      'html_url': 'https://github.com/krzema12',
#      'followers_url': 'https://api.github.com/users/krzema12/followers',
#      'following_url': 'https://api.github.com/users/krzema12/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/krzema12/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/krzema12/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/krzema12/subscriptions',
#      'organizations_url': 'https://api.github.com/users/krzema12/orgs',
#      'repos_url': 'https://api.github.com/users/krzema12/repos',
#      'events_url': 'https://api.github.com/users/krzema12/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/krzema12/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'krzema12',
#       'id': 3110813,
#       'node_id': 'MDQ6VXNlcjMxMTA4MTM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/3110813?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/krzema12',
#       'html_url': 'https://github.com/krzema12',
#       'followers_url': 'https://api.github.com/users/krzema12/followers',
#       'following_url': 'https://api.github.com/users/krzema12/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/krzema12/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/krzema12/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/krzema12/subscriptions',
#       'organizations_url': 'https://api.github.com/users/krzema12/orgs',
#       'repos_url': 'https://api.github.com/users/krzema12/repos',
#       'events_url': 'https://api.github.com/users/krzema12/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/krzema12/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2021-11-21T20:08:45Z',
#     'updated_at': '2021-11-23T11:56:27Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': "See https://kotlinlang.slack.com/archives/C0289CS37AS/p1637517359061900?thread_ts=1637517359.061900&cid=C0289CS37AS\r\n\r\nhttps://core-electronics.com.au/tutorials/Python_and_MicroPython.html\r\n\r\nLet's check how costly it would be to support both regular Python and Micropython (MP).\r\n\r\nIdeas/steps:\r\n\r\n- [X] check if there's a regular Linux interpreter for MP\r\n- [X] smoke test: try running a sample output from current Kotlin Python compiler and see how it goes\r\n- [ ] run box tests with MP interpreter and see what's the success rate comparing to what we have on Python\r\n- [ ] hook MP interpreter into the box tests so that CI runs both\r\n- [ ] think of cases where it would be challenging to support both at the same time",
#     'reactions': {'url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/51/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/51/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/comments/976441432',
#     'html_url': 'https://github.com/krzema12/kotlin-python/issues/51#issuecomment-976441432',
#     'issue_url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/51',
#     'id': 976441432,
#     'node_id': 'IC_kwDOEpl9oc46M1BY',
#     'user': {'login': 'krzema12',
#      'id': 3110813,
#      'node_id': 'MDQ6VXNlcjMxMTA4MTM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3110813?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/krzema12',
#      'html_url': 'https://github.com/krzema12',
#      'followers_url': 'https://api.github.com/users/krzema12/followers',
#      'following_url': 'https://api.github.com/users/krzema12/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/krzema12/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/krzema12/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/krzema12/subscriptions',
#      'organizations_url': 'https://api.github.com/users/krzema12/orgs',
#      'repos_url': 'https://api.github.com/users/krzema12/repos',
#      'events_url': 'https://api.github.com/users/krzema12/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/krzema12/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-11-23T11:56:27Z',
#     'updated_at': '2021-11-23T11:56:27Z',
#     'author_association': 'OWNER',
#     'body': "Thanks! I propose (especially in such seemingly simple cases) is to emit such Python code that works for both Pythons. The compilation flag introduces some extra complexity, maybe we'll need it in the future, though.\r\n\r\nMy first step towards supporting MicroPython is adding some flag to the box tests that selects Python interpreter (#75). Let's then compare the outputs and see what tests pass in regular Python and fail in MP so far, then we can learn about more differences in practice.\r\n\r\nTwo good news I see:\r\n* passing https://github.com/krzema12/kotlin-python/blob/python-backend/python/experiments/out_ir.py to `micropython` yields no parsing issues, which means that the Python generated for the JS IR is correctly parsed by MicroPython (not yet executed!)\r\n* we're just starting implementing our stdlib, so we'll be able to take into account both pythons already",
#     'reactions': {'url': 'https://api.github.com/repos/krzema12/kotlin-python/issues/comments/976441432/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-23T11:56:27Z'}]

# %%
from IPython.display import JSON
JSON(response.json())

# %%
len(github_response)
# Out:
# 30

# %%
#login
github_response[3]["actor"]["login"]
# Out:
# 'beau1004'

# %% [markdown]
# ### Exercise:
#
# Extract the "login", the repo name and the event type for each event.

# %%
# Code
for resp in github_response:
    login = resp["actor"]["login"]
    repo_name = resp["repo"]["name"]
    event_type = resp["type"]
    print(login, ' - ', repo_name, ' - ', event_type,'\n')
# Out:
# Sakura202119  -  Sakura202119/Sakura202119.githup.io  -  PushEvent
#
# beau1004  -  beau1004/-db  -  PushEvent
#
# hunojung  -  hunojung/hunojung.github.io  -  PushEvent
#
# beau1004  -  beau1004/-db  -  PushEvent
#
# codestar-github-bot-1  -  codestar-github-bot-1/user-public-seeded-repo-ap-southeast-1  -  CreateEvent
#
# jon-shipley  -  DFEAGILEDEVOPS/MTC  -  PullRequestReviewEvent
#
# arunava-webdev4u  -  arunava-webdev4u/Projects  -  PushEvent
#
# Rodriguesss  -  Douglas-CRVG/Driven-BuzzQuizz  -  PushEvent
#
# stockiNail  -  chartjs/chartjs-plugin-annotation  -  PullRequestEvent
#
# max-moser  -  max-moser/invenio-requests  -  PushEvent
#
# github-actions[bot]  -  icedmoca/icedmoca  -  PushEvent
#
# pauldambra  -  PostHog/posthog  -  PullRequestReviewCommentEvent
#
# fuadsuleyman  -  fuadsuleyman/go-auth  -  PushEvent
#
# gitpod-io[bot]  -  aws/aws-cdk  -  IssueCommentEvent
#
# jchristgit  -  python-discord/kubernetes  -  PullRequestReviewEvent
#
# shopwareBot  -  shopware/platform  -  PushEvent
#
# L1B0  -  hvmi/hvmi  -  WatchEvent
#
# andriikorotkov  -  airbytehq/airbyte  -  PushEvent
#
# phweyland  -  phweyland/darktable  -  CreateEvent
#
# jinpengLei  -  jinpengLei/ctr2021  -  PushEvent
#
# alexzautke  -  medizininformatik-initiative/usecase-highmed-ic  -  PushEvent
#
# billybobza  -  newstools/2021-leadership-newspaper-nigeria  -  PushEvent
#
# richardborgescc  -  richardborgescc/always-learning  -  PullRequestEvent
#
# kogre  -  CitizenLabDotCo/citizenlab  -  PushEvent
#
# harikiran-01  -  harikiran-01/IJournall  -  PullRequestEvent
#
# pauldambra  -  PostHog/posthog  -  PullRequestReviewEvent
#
# Rodriguesss  -  Douglas-CRVG/Driven-BuzzQuizz  -  PullRequestEvent
#
# jasonwilliams  -  microsoft/vscode-extension-samples  -  IssuesEvent
#
# OnkelDok  -  buchen/portfolio  -  IssueCommentEvent
#
# krzema12  -  krzema12/kotlin-python  -  IssueCommentEvent

# %% [markdown]
# ### Intenational Space Station
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'timestamp': 1637668889,
#  'message': 'success',
#  'iss_position': {'longitude': '-127.7336', 'latitude': '-23.7040'}}

# %% [markdown]
# ## Spotipy
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into an Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %% [markdown]
# #### Authentification
#
# Follow the wrapper for the API docs: https://spotipy.readthedocs.io/en/2.16.1/

# %%
#  !pip install spotipy

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(
    client_credentials_manager=SpotifyClientCredentials(
    client_id="18fc53d405314bcc8ddd925a29cbfaab",
    client_secret="fd9e1f691891473098023b19475b267a"))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This function allows you to find songs with using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
JSON(results)

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: you know that because the dictionary is wrapped by square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features:

# %%
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# This is how Spotify identifies individual songs: with an `uri`. (the `id` and the `url` are also ways to identify uniquely each song).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chilli Peppers and store the `uri` of the songs and their names.

# %%
# send request and store the response
red_hot = sp.search(q="Red hot chili peppers", limit=10)

# initialize empty lists to store stuff later
list_of_uri = []
list_of_song_names = []

# iterate through the "items" (the songs), and append
# the "uri" and the "name" to the lists we created
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# print results
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:1XxCiPw07rd1ytYnE7SoJI', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:4nRi0PlIpoy9SyySD1IDGY', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Around the World', "Can't Stop", 'Buried Alive', "Road Trippin'", 'Californication', 'By the Way - Live', 'Snow (Hey Oh)', 'Pedigree']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results into a big list called `results`.

# %%
artists = ["Red hot chili peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
results
# Out:
# [{'tracks': {'href': 'https://api.spotify.com/v1/search?query=Red+hot+chili+peppers&type=track&offset=0&limit=10',
#    'items': [{'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/30Perjew8HyGkdSmqguYyg'},
#       'href': 'https://api.spotify.com/v1/albums/30Perjew8HyGkdSmqguYyg',
#       'id': '30Perjew8HyGkdSmqguYyg',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273153d79816d853f2694b2cc70',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02153d79816d853f2694b2cc70',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851153d79816d853f2694b2cc70',
#         'width': 64}],
#       'name': 'Blood Sugar Sex Magik (Deluxe Edition)',
#       'release_date': '1991-09-24',
#       'release_date_precision': 'day',
#       'total_tracks': 19,
#       'type': 'album',
#       'uri': 'spotify:album:30Perjew8HyGkdSmqguYyg'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 264306,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19901576'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3d9DChrdc6BOeFsbrZ3Is0'},
#      'href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#      'id': '3d9DChrdc6BOeFsbrZ3Is0',
#      'is_local': False,
#      'name': 'Under the Bridge',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/90e41778392f27b6f7dd82db4c90916b3727aa6a?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 11,
#      'type': 'track',
#      'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#         'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#         'id': '0NB5HROxc8dDBXpkIi1v3d',
#         'name': 'Remi Wolf',
#         'type': 'artist',
#         'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7tJ8Wtej161vR0uCbGDiDR'},
#       'href': 'https://api.spotify.com/v1/albums/7tJ8Wtej161vR0uCbGDiDR',
#       'id': '7tJ8Wtej161vR0uCbGDiDR',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27316a6cb93e32bf2ae66b1f5b2',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0216a6cb93e32bf2ae66b1f5b2',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485116a6cb93e32bf2ae66b1f5b2',
#         'width': 64}],
#       'name': 'Juno',
#       'release_date': '2021-10-15',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7tJ8Wtej161vR0uCbGDiDR'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NB5HROxc8dDBXpkIi1v3d'},
#        'href': 'https://api.spotify.com/v1/artists/0NB5HROxc8dDBXpkIi1v3d',
#        'id': '0NB5HROxc8dDBXpkIi1v3d',
#        'name': 'Remi Wolf',
#        'type': 'artist',
#        'uri': 'spotify:artist:0NB5HROxc8dDBXpkIi1v3d'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 171897,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUG12103572'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3xJu5hrOU9OvFQSGLQiwQS'},
#      'href': 'https://api.spotify.com/v1/tracks/3xJu5hrOU9OvFQSGLQiwQS',
#      'id': '3xJu5hrOU9OvFQSGLQiwQS',
#      'is_local': False,
#      'name': 'Anthony Kiedis',
#      'popularity': 60,
#      'preview_url': None,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/0fLhefnjlIV3pGNF9Wo8CD'},
#       'href': 'https://api.spotify.com/v1/albums/0fLhefnjlIV3pGNF9Wo8CD',
#       'id': '0fLhefnjlIV3pGNF9Wo8CD',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a9249ebb15ca7a5b75f16a90',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a9249ebb15ca7a5b75f16a90',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a9249ebb15ca7a5b75f16a90',
#         'width': 64}],
#       'name': 'Californication',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:0fLhefnjlIV3pGNF9Wo8CD'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 239213,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900687'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1Y6DGcTCuMAtw8KB3h4W3q'},
#      'href': 'https://api.spotify.com/v1/tracks/1Y6DGcTCuMAtw8KB3h4W3q',
#      'id': '1Y6DGcTCuMAtw8KB3h4W3q',
#      'is_local': False,
#      'name': 'Around the World',
#      'popularity': 51,
#      'preview_url': 'https://p.scdn.co/mp3-preview/79ddc3851069cf64e6b11574b7414477ddf275d6?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1Y6DGcTCuMAtw8KB3h4W3q'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6deiaArbeoqp1xPEGdEKp1'},
#       'href': 'https://api.spotify.com/v1/albums/6deiaArbeoqp1xPEGdEKp1',
#       'id': '6deiaArbeoqp1xPEGdEKp1',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273de1af2785a83cc660155a0c4',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02de1af2785a83cc660155a0c4',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851de1af2785a83cc660155a0c4',
#         'width': 64}],
#       'name': 'By the Way (Deluxe Edition)',
#       'release_date': '2002-07-09',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:6deiaArbeoqp1xPEGdEKp1'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 269000,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB10201694'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3ZOEytgrvLwQaqXreDs2Jx'},
#      'href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#      'id': '3ZOEytgrvLwQaqXreDs2Jx',
#      'is_local': False,
#      'name': "Can't Stop",
#      'popularity': 80,
#      'preview_url': 'https://p.scdn.co/mp3-preview/076f7d75404dfd18964d60da63d1855b192f3e62?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 7,
#      'type': 'track',
#      'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#         'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#         'id': '4xRYI6VqpkE3UwrDrAZL8L',
#         'name': 'Logic',
#         'type': 'artist',
#         'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1Mk7Lei0Ra3hawezqmad5V'},
#       'href': 'https://api.spotify.com/v1/albums/1Mk7Lei0Ra3hawezqmad5V',
#       'id': '1Mk7Lei0Ra3hawezqmad5V',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a4c35326f6fe6676c10e31ac',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a4c35326f6fe6676c10e31ac',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a4c35326f6fe6676c10e31ac',
#         'width': 64}],
#       'name': 'Under Pressure (Deluxe)',
#       'release_date': '2014-10-21',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:1Mk7Lei0Ra3hawezqmad5V'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'},
#        'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L',
#        'id': '4xRYI6VqpkE3UwrDrAZL8L',
#        'name': 'Logic',
#        'type': 'artist',
#        'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 337746,
#      'explicit': True,
#      'external_ids': {'isrc': 'USUM71414218'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0Kojfmpnf0A2yC1zyv39Zx'},
#      'href': 'https://api.spotify.com/v1/tracks/0Kojfmpnf0A2yC1zyv39Zx',
#      'id': '0Kojfmpnf0A2yC1zyv39Zx',
#      'is_local': False,
#      'name': 'Buried Alive',
#      'popularity': 53,
#      'preview_url': None,
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 204973,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900700'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1XxCiPw07rd1ytYnE7SoJI'},
#      'href': 'https://api.spotify.com/v1/tracks/1XxCiPw07rd1ytYnE7SoJI',
#      'id': '1XxCiPw07rd1ytYnE7SoJI',
#      'is_local': False,
#      'name': "Road Trippin'",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/44653117c32f12cb2af30093736571893ff4c694?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 15,
#      'type': 'track',
#      'uri': 'spotify:track:1XxCiPw07rd1ytYnE7SoJI'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#         'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#         'id': '0L8ExT028jH3ddEcZwqJJ5',
#         'name': 'Red Hot Chili Peppers',
#         'type': 'artist',
#         'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PT',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RW',
#        'SA',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TR',
#        'TT',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'},
#       'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi',
#       'id': '2Y9IRtehByVkegoD7TcLfi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595',
#         'width': 64}],
#       'name': 'Californication (Deluxe Edition)',
#       'release_date': '1999-06-08',
#       'release_date_precision': 'day',
#       'total_tracks': 18,
#       'type': 'album',
#       'uri': 'spotify:album:2Y9IRtehByVkegoD7TcLfi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 329733,
#      'explicit': False,
#      'external_ids': {'isrc': 'USWB19900690'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/48UPSzbZjgc449aqz8bxox'},
#      'href': 'https://api.spotify.com/v1/tracks/48UPSzbZjgc449aqz8bxox',
#      'id': '48UPSzbZjgc449aqz8bxox',
#      'is_local': False,
#      'name': 'Californication',
#      'popularity': 81,
#      'preview_url': 'https://p.scdn.co/mp3-preview/175ce440229d2fb5361756f3e68c9647b86a8eee?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:48UPSzbZjgc449aqz8bxox'},
#     {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         'id': '0LyfQWJT6nXafLPZqxe9Of',
#         'name': 'Various Artists',
#         'type': 'artist',
#         'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       'available_markets': ['CA', 'US'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4US5ARBYbzQI177Tc5J37t'},
#       'href': 'https://api.spotify.com/v1/albums/4US5ARBYbzQI177Tc5J37t',
#       'id': '4US5ARBYbzQI177Tc5J37t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273c2244fca50540dc4df3b6bbf',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02c2244fca50540dc4df3b6bbf',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851c2244fca50540dc4df3b6bbf',
#         'width': 64}],
#       'name': 'The Rock & Roll Hall Of Fame: In Concert 2012 & 2013 (Live)',
#       'release_date': '2018-04-24',
#       'release_date_precision': 'day',
#       'total_tracks': 22,
#       'type': 'album',
#       'uri': 'spotify:album:4US5ARBYbzQI177Tc5J37t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#        'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#        'id': '0L8ExT028jH3ddEcZwqJJ5',
#        'name': 'Red Hot Chili Peppers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}],
#      'available_markets': ['CA', 'US'],
#      'disc_number': 1,
#      'duration_ms': 217351,
#      'explicit': False,
#      'external_ids': {'isrc': 'USYRC1800031'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4nRi0PlIpoy9SyySD1IDGY'},
#      'href': 'https://api.spotify.com/v1/tracks/4nRi0PlIpoy9SyySD1IDGY',
#      'id': '4nRi0PlIpoy9SyySD1IDGY',
#      'is_local': False,
#      'name': 'By the Way - Live',
#      'popularity': 10,
#      'preview_url': 'https://p.scdn.co/mp3-preview/e073ea994d91d77841fee33c8db3e1d76850beea?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:4nRi0PlIpoy9SyySD1IDGY'},
#     {'album': {'album_type': 'album',
# ...
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 277240,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500147'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0t6DdFmFQhQYWhmfa5FJer'},
#      'href': 'https://api.spotify.com/v1/tracks/0t6DdFmFQhQYWhmfa5FJer',
#      'id': '0t6DdFmFQhQYWhmfa5FJer',
#      'is_local': False,
#      'name': 'You Give Good Love',
#      'popularity': 52,
#      'preview_url': 'https://p.scdn.co/mp3-preview/dc77dfeffba6def27cfaec208623ab82cc33cacc?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:0t6DdFmFQhQYWhmfa5FJer'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2MH37enG6IPvNK5QFLyKes'},
#       'href': 'https://api.spotify.com/v1/albums/2MH37enG6IPvNK5QFLyKes',
#       'id': '2MH37enG6IPvNK5QFLyKes',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732ae4fcec560ab559d6f5dc88',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022ae4fcec560ab559d6f5dc88',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512ae4fcec560ab559d6f5dc88',
#         'width': 64}],
#       'name': 'Whitney Houston',
#       'release_date': '1985-02-14',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:2MH37enG6IPvNK5QFLyKes'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 275533,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18500150'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5tdKaKLnC4SgtDZ6RlWeal'},
#      'href': 'https://api.spotify.com/v1/tracks/5tdKaKLnC4SgtDZ6RlWeal',
#      'id': '5tdKaKLnC4SgtDZ6RlWeal',
#      'is_local': False,
#      'name': 'How Will I Know',
#      'popularity': 70,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4cfd0ab2b770e37313275d37788f687992b0ee17?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:5tdKaKLnC4SgtDZ6RlWeal'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#         'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#         'id': '6XpaIBNiVzIetEPCWDvAFP',
#         'name': 'Whitney Houston',
#         'type': 'artist',
#         'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CD',
#        'CG',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IQ',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'LY',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TJ',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VE',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5Vdzprr5cOqXQo44eHeV7t'},
#       'href': 'https://api.spotify.com/v1/albums/5Vdzprr5cOqXQo44eHeV7t',
#       'id': '5Vdzprr5cOqXQo44eHeV7t',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273cc57e9b00b87dd0f6e868347',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02cc57e9b00b87dd0f6e868347',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851cc57e9b00b87dd0f6e868347',
#         'width': 64}],
#       'name': 'Whitney',
#       'release_date': '1987-06-02',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:5Vdzprr5cOqXQo44eHeV7t'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#        'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#        'id': '6XpaIBNiVzIetEPCWDvAFP',
#        'name': 'Whitney Houston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6XpaIBNiVzIetEPCWDvAFP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 305066,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAR18700115'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/19wadMw1A8XejDV4p5wMt1'},
#      'href': 'https://api.spotify.com/v1/tracks/19wadMw1A8XejDV4p5wMt1',
#      'id': '19wadMw1A8XejDV4p5wMt1',
#      'is_local': False,
#      'name': "Didn't We Almost Have It All",
#      'popularity': 61,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7411cc6a36f98f46a2890f6f322605021db0f3c2?cid=18fc53d405314bcc8ddd925a29cbfaab',
#      'track_number': 4,
#      'type': 'track',
#      'uri': 'spotify:track:19wadMw1A8XejDV4p5wMt1'}],
#    'limit': 10,
#    'next': 'https://api.spotify.com/v1/search?query=Whitney+Houston&type=track&offset=10&limit=10',
#    'offset': 0,
#    'previous': None,
#    'total': 5827}}]

# %% [markdown]
# We can iterate through the `results` list and get the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Around the World',
#  "Can't Stop",
#  'Buried Alive',
#  "Road Trippin'",
#  'Californication',
#  'By the Way - Live',
#  'Snow (Hey Oh)',
#  'Pedigree',
#  'Scarred From Love',
#  'Emotionally Scarred',
#  'SCARR',
#  'Scarred',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred Island',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  'Scarred',
#  'Rolling Loud (feat. Big Scarr, BigWalkDog)',
#  'Free Smoke (feat. Big Scarr)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'The Star Spangled Banner (feat. The Florida Orchestra) - Live from Super Bowl XXV',
#  'Higher Love',
#  'I Look to You',
#  'I Will Always Love You',
#  'Exhale (Shoop Shoop) - from "Waiting to Exhale" - Original Soundtrack',
#  'I Have Nothing',
#  'You Give Good Love',
#  'How Will I Know',
#  "Didn't We Almost Have It All"]

# %% [markdown]
# #### Exploring the tracks

# %%
# Get artist id's for all the tracks you found

query = "Despacito"

Despacito = sp.search(q = query, limit = 50)

# %%
Despacito_artists = set()

for item in Despacito["tracks"]["items"]:
    for artist in item["artists"]:
        Despacito_artists.add(artist["uri"])

# %%
Despacito["tracks"]["items"][2]["artists"][0]["name"]
# Out:
# 'Luis Fonsi'

# %%
Despacito_artists
# Out:
# {'spotify:artist:0NxhAEPOSeCg6vypFr7yjU',
#  'spotify:artist:0QNakySWugkMvfwbDoaY9L',
#  'spotify:artist:0fIdQWpwzU2oEtsoyArDOL',
#  'spotify:artist:0r3y7sISJoUIfT5E85AYII',
#  'spotify:artist:1NiC1V6xc8OR1ERiIoCvtx',
#  'spotify:artist:1Uz4WPsI4VylKT6lhJiDO5',
#  'spotify:artist:1emgbX82aLN8eCS3AnXFfC',
#  'spotify:artist:1mX1TWKpNxDSAH16LgDfiR',
#  'spotify:artist:1qwVM2JnEMXbKgvZESGsRn',
#  'spotify:artist:1rVo9h17cHhWerDiZj0yXH',
#  'spotify:artist:1sJhbiQRSIKZeTYEZfzBSV',
#  'spotify:artist:1uNFoZAHBGtllmzznpCI3s',
#  'spotify:artist:1uj8EOCKAXn4w2TR7CVnQb',
#  'spotify:artist:26AHtbjWKiwYzsoGoUZq53',
#  'spotify:artist:2T06whb4s6UiufL1j5Qtz9',
#  'spotify:artist:2VAjBQ6cM2faT2UKxONV93',
#  'spotify:artist:3YfvowVavHTzXLKmKaYM1c',
#  'spotify:artist:3YrM00mKs7wqOtBPmeSoEo',
#  'spotify:artist:3vOJJbGGUOtC9csissiL0G',
#  'spotify:artist:4KLOMib6zqzNayKwLWTs2Q',
#  'spotify:artist:4L5SLCIDWPPNGzrLraYCOS',
#  'spotify:artist:4N5fp4zhTsVITZTVfsXpc2',
#  'spotify:artist:4V8Sr092TqfHkfAA5fXXqG',
#  'spotify:artist:4VMYDCV2IEDYJArk749S6m',
#  'spotify:artist:4fdxbJLSNRIMkMGbLs5QPF',
#  'spotify:artist:4j4Lq1ut4h3H3eTIubtyog',
#  'spotify:artist:5DsbNI5ZIDIWjmsAdaYvZ2',
#  'spotify:artist:5HPu6u2rDA0f6jp51xZAEq',
#  'spotify:artist:5KWOCu1saEHAhPiLKlOLIy',
#  'spotify:artist:5tqJLLaSDpdhDAwqWgAdXM',
#  'spotify:artist:62rnGiDozQmBBk5yM21yOC',
#  'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4',
#  'spotify:artist:6MERXsiRbur2oJZFgYRDKz',
#  'spotify:artist:6QtqvuYuaOJy4te3nfkHKK',
#  'spotify:artist:6RTlv2UCWtRggV0rIo5TrN',
#  'spotify:artist:6U3ybJ9UHNKEdsH7ktGBZ7',
#  'spotify:artist:6dBIk14xcZqU0cRsyjXNkX',
#  'spotify:artist:6mU8ucezzms5I2kNH6HNlu',
#  'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R',
#  'spotify:artist:72iuahEAHKaMzDXKVw6e8P',
#  'spotify:artist:738wLrAtLtCtFOLvQBXOXp',
#  'spotify:artist:7CQwac16i1W5ej8YpuL3dv',
#  'spotify:artist:7dTPvuNcEXLkQ1XiAuiWIP',
#  'spotify:artist:7p3ipw2PvGG0X2x6zL1DLO',
#  'spotify:artist:7y33enVLfDvft6HGNmcxdV'}

# %% [markdown]
# ### Playlists

# %%
my_playlist = sp.user_playlist_tracks(user="spotify",
                                      playlist_id="https://open.spotify.com/playlist/24T3swe0HN7JWLfsDcakHw?si=ce24270cef314a9a")

# %% [markdown]
# Extract all songs IDs from a playlist

# %%
JSON(my_playlist)

# %%
my_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/24T3swe0HN7JWLfsDcakHw/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-01-30T09:02:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CIMQHirSU0MQqyYHq0eOx'},
#        'href': 'https://api.spotify.com/v1/artists/2CIMQHirSU0MQqyYHq0eOx',
#        'id': '2CIMQHirSU0MQqyYHq0eOx',
#        'name': 'deadmau5',
#        'type': 'artist',
#        'uri': 'spotify:artist:2CIMQHirSU0MQqyYHq0eOx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6WJvrBlL3zgu4mVoKyvMkl'},
#      'href': 'https://api.spotify.com/v1/albums/6WJvrBlL3zgu4mVoKyvMkl',
#      'id': '6WJvrBlL3zgu4mVoKyvMkl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d49d976721f4dc6b3c6225ad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d49d976721f4dc6b3c6225ad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d49d976721f4dc6b3c6225ad',
#        'width': 64}],
#      'name': 'For Lack Of A Better Name',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6WJvrBlL3zgu4mVoKyvMkl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CIMQHirSU0MQqyYHq0eOx'},
#       'href': 'https://api.spotify.com/v1/artists/2CIMQHirSU0MQqyYHq0eOx',
#       'id': '2CIMQHirSU0MQqyYHq0eOx',
#       'name': 'deadmau5',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CIMQHirSU0MQqyYHq0eOx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 3959893,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBTDG0900149'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3v4HvdYsdAc8K9Fy5SdyGe'},
#     'href': 'https://api.spotify.com/v1/tracks/3v4HvdYsdAc8K9Fy5SdyGe',
#     'id': '3v4HvdYsdAc8K9Fy5SdyGe',
#     'is_local': False,
#     'name': 'For Lack Of A Better Name - Mixed Version',
#     'popularity': 21,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3v4HvdYsdAc8K9Fy5SdyGe'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 387506,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eS6pTvDNOvh2kyxeZtK3r'},
#     'href': 'https://api.spotify.com/v1/tracks/5eS6pTvDNOvh2kyxeZtK3r',
#     'id': '5eS6pTvDNOvh2kyxeZtK3r',
#     'is_local': False,
#     'name': 'Robot Rock / Oh Yeah',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7a72ef3ab554e6a0aec213fbfa1756d444edaf9e?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5eS6pTvDNOvh2kyxeZtK3r'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 329653,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBDUW0700002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4IdiGMOzEYXOh2897XOV8i'},
#     'href': 'https://api.spotify.com/v1/tracks/4IdiGMOzEYXOh2897XOV8i',
#     'id': '4IdiGMOzEYXOh2897XOV8i',
#     'is_local': False,
#     'name': 'Touch It / Technologic',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/71c958b90ea51e487f842e132236008c5986ef9e?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4IdiGMOzEYXOh2897XOV8i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 290840,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1E8S3CSv20KrKT0C1yAjkO'},
#     'href': 'https://api.spotify.com/v1/tracks/1E8S3CSv20KrKT0C1yAjkO',
#     'id': '1E8S3CSv20KrKT0C1yAjkO',
#     'is_local': False,
#     'name': 'Television Rules the Nation / Crescendolls',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0eaa9f74ca537bbaf7e34f970206868faa4ce3cb?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1E8S3CSv20KrKT0C1yAjkO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 421600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700004'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3n4ow4XGzwSIPxA3JHLF9p'},
#     'href': 'https://api.spotify.com/v1/tracks/3n4ow4XGzwSIPxA3JHLF9p',
#     'id': '3n4ow4XGzwSIPxA3JHLF9p',
#     'is_local': False,
#     'name': 'Too Long / Steam Machine',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bb029a3b48b31f515838b09ff2065dd724467527?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3n4ow4XGzwSIPxA3JHLF9p'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 342626,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RByQFt9Mlo8hDYJ921tCv'},
#     'href': 'https://api.spotify.com/v1/tracks/5RByQFt9Mlo8hDYJ921tCv',
#     'id': '5RByQFt9Mlo8hDYJ921tCv',
#     'is_local': False,
#     'name': 'Around the World / Harder, Better, Faster, Stronger',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/029d59d938437b6735214573954dcc488c541264?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5RByQFt9Mlo8hDYJ921tCv'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7u6zL7kqpgLPISZYXNTgYk'},
#      'href': 'https://api.spotify.com/v1/albums/7u6zL7kqpgLPISZYXNTgYk',
#      'id': '7u6zL7kqpgLPISZYXNTgYk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273673288fb985e5c194536ae27',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02673288fb985e5c194536ae27',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851673288fb985e5c194536ae27',
#        'width': 64}],
#      'name': 'Alive 2007',
#      'release_date': '2007-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:7u6zL7kqpgLPISZYXNTgYk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#       'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#       'id': '4tZwfgrHOc3mvqYlEYSvVi',
#       'name': 'Daft Punk',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 431506,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDUW0700006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Ons6C3wXBMi8nYpLBMlVe'},
#     'href': 'https://api.spotify.com/v1/tracks/3Ons6C3wXBMi8nYpLBMlVe',
#     'id': '3Ons6C3wXBMi8nYpLBMlVe',
#     'is_local': False,
#     'name': "Burnin' / Too Long",
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5b507a0f17ee87689ba19d8585cd2d1a8a01bf6?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3Ons6C3wXBMi8nYpLBMlVe'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-01-30T09:03:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#        'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#        'id': '4tZwfgrHOc3mvqYlEYSvVi',
#        'name': 'Daft Punk',
#        'type': 'artist',
#        'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CI',
#       'CL',
#       'CM',
# ...
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 423453,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBMQ0100039'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/677Ha6CaBmcGRvuyEnQeI8'},
#     'href': 'https://api.spotify.com/v1/tracks/677Ha6CaBmcGRvuyEnQeI8',
#     'id': '677Ha6CaBmcGRvuyEnQeI8',
#     'is_local': False,
#     'name': 'Song for Shelter - Chemical Brothers Remix',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0e4305e47a9019b0e2a6055429b9b170cfc13f81?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:677Ha6CaBmcGRvuyEnQeI8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-11-23T10:01:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Y7tXHSEejGu1vQ9bwDdXW'},
#        'href': 'https://api.spotify.com/v1/artists/4Y7tXHSEejGu1vQ9bwDdXW',
#        'id': '4Y7tXHSEejGu1vQ9bwDdXW',
#        'name': 'Fatboy Slim',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Y7tXHSEejGu1vQ9bwDdXW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5vpSQUagobcDEf6IVcmM1m'},
#      'href': 'https://api.spotify.com/v1/albums/5vpSQUagobcDEf6IVcmM1m',
#      'id': '5vpSQUagobcDEf6IVcmM1m',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739737959b4ac5694679793e66',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029737959b4ac5694679793e66',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519737959b4ac5694679793e66',
#        'width': 64}],
#      'name': 'Why Try Harder - The Greatest Hits',
#      'release_date': '2006-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:5vpSQUagobcDEf6IVcmM1m'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Y7tXHSEejGu1vQ9bwDdXW'},
#       'href': 'https://api.spotify.com/v1/artists/4Y7tXHSEejGu1vQ9bwDdXW',
#       'id': '4Y7tXHSEejGu1vQ9bwDdXW',
#       'name': 'Fatboy Slim',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Y7tXHSEejGu1vQ9bwDdXW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 356466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBMQ9800127'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6paZrls0zGv4bsbtFf4Ykm'},
#     'href': 'https://api.spotify.com/v1/tracks/6paZrls0zGv4bsbtFf4Ykm',
#     'id': '6paZrls0zGv4bsbtFf4Ykm',
#     'is_local': False,
#     'name': "Rockafeller Skank - Mulder's Urban Takeover Mix",
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2828076e4cadd0795c87724e1814f45aef4d4b5c?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 21,
#     'type': 'track',
#     'uri': 'spotify:track:6paZrls0zGv4bsbtFf4Ykm'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-11-23T10:01:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klave_n_roll'},
#     'href': 'https://api.spotify.com/v1/users/klave_n_roll',
#     'id': 'klave_n_roll',
#     'type': 'user',
#     'uri': 'spotify:user:klave_n_roll'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Y7tXHSEejGu1vQ9bwDdXW'},
#        'href': 'https://api.spotify.com/v1/artists/4Y7tXHSEejGu1vQ9bwDdXW',
#        'id': '4Y7tXHSEejGu1vQ9bwDdXW',
#        'name': 'Fatboy Slim',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Y7tXHSEejGu1vQ9bwDdXW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5vpSQUagobcDEf6IVcmM1m'},
#      'href': 'https://api.spotify.com/v1/albums/5vpSQUagobcDEf6IVcmM1m',
#      'id': '5vpSQUagobcDEf6IVcmM1m',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739737959b4ac5694679793e66',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029737959b4ac5694679793e66',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519737959b4ac5694679793e66',
#        'width': 64}],
#      'name': 'Why Try Harder - The Greatest Hits',
#      'release_date': '2006-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:5vpSQUagobcDEf6IVcmM1m'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Y7tXHSEejGu1vQ9bwDdXW'},
#       'href': 'https://api.spotify.com/v1/artists/4Y7tXHSEejGu1vQ9bwDdXW',
#       'id': '4Y7tXHSEejGu1vQ9bwDdXW',
#       'name': 'Fatboy Slim',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Y7tXHSEejGu1vQ9bwDdXW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 541773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBMQ0500063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1nhmSyFXTALoOVfUt26km5'},
#     'href': 'https://api.spotify.com/v1/tracks/1nhmSyFXTALoOVfUt26km5',
#     'id': '1nhmSyFXTALoOVfUt26km5',
#     'is_local': False,
#     'name': 'Mi Bebe Masoquista - X-Press 2 Remix',
#     'popularity': 15,
#     'preview_url': 'https://p.scdn.co/mp3-preview/07243d6e4fc31978489cfbe6d5f2efaffc4aabd2?cid=18fc53d405314bcc8ddd925a29cbfaab',
#     'track': True,
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:1nhmSyFXTALoOVfUt26km5'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 95}

# %%
my_playlist["items"][0]["track"]["name"]
# Out:
# 'For Lack Of A Better Name - Mixed Version'

# %%
my_playlist["items"][0]["track"]["id"]
# Out:
# '3v4HvdYsdAc8K9Fy5SdyGe'

# %%
my_playlist["items"][0]["track"]["name"]
# Out:
# 'For Lack Of A Better Name - Mixed Version'

# %%
len(my_playlist["items"])
# Out:
# 95

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %%
sp.audio_features("spotify:track:3d9DChrdc6BOeFsbrZ3Is0")
# Out:
# [{'danceability': 0.559,
#   'energy': 0.345,
#   'key': 4,
#   'loudness': -13.496,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.0576,
#   'instrumentalness': 0.000105,
#   'liveness': 0.141,
#   'valence': 0.458,
#   'tempo': 84.581,
#   'type': 'audio_features',
#   'id': '3d9DChrdc6BOeFsbrZ3Is0',
#   'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#   'duration_ms': 264307,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Create a function that takes a song name and returns its audio features

# %% [markdown]
# # An ATTEMPT with def - For Loop

# %%
#function building
def get_audio_feat_song(song_name):
    result = sp.search(q=song_name, limit=1)
    uri = result["tracks"]["items"][0]["uri"]
    return sp.audio_features(uri)

# %%
get_audio_feat_song("Sailing to Philadelphia")

# %%
# Code
def song_features(song):
    for track in range(len(my_playlist["items"])):
                if song==my_playlist["items"][track]["track"]["name"]:
                    features = sp.audio_features(my_playlist["items"][track]["track"]["id"])
                    print(features)
                break

            
            
song_features("For Lack Of A Better Name - Mixed Version")

# %%
type(my_playlist)
# Out:
# dict

# %%
for track in my_playlist:
    print(track)
# Out:
# href
# items
# limit
# next
# offset
# previous
# total

# %%
# song_features('One More Time / Aerodynamic')
song_features("For Lack Of A Better Name - Mixed Version")
# Out:
# [{'danceability': 0.738, 'energy': 0.735, 'key': 6, 'loudness': -8.769, 'mode': 0, 'speechiness': 0.065, 'acousticness': 0.00883, 'instrumentalness': 0.762, 'liveness': 0.105, 'valence': 0.0384, 'tempo': 128.008, 'type': 'audio_features', 'id': '3v4HvdYsdAc8K9Fy5SdyGe', 'uri': 'spotify:track:3v4HvdYsdAc8K9Fy5SdyGe', 'track_href': 'https://api.spotify.com/v1/tracks/3v4HvdYsdAc8K9Fy5SdyGe', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3v4HvdYsdAc8K9Fy5SdyGe', 'duration_ms': 3959893, 'time_signature': 4}]

# %%
# Code
def song_names_output():
    for track in range(len(my_playlist["items"])):
            print(my_playlist["items"][track]["track"]["name"])

# %%
song_names_output()
# Out:
# For Lack Of A Better Name - Mixed Version
# Robot Rock / Oh Yeah
# Touch It / Technologic
# Television Rules the Nation / Crescendolls
# Too Long / Steam Machine
# Around the World / Harder, Better, Faster, Stronger
# Burnin' / Too Long
# Face to Face / Short Circuit
# One More Time / Aerodynamic
# Aerodynamic Beats / Gabrielle , Forget About the World
# Prime Time of Your Life / Brainwasher / Rollin' & Scratchin' / Alive
# Da Funk / Daftendirekt
# Superheroes / Human After All / Rock'n Roll
# Human After All / Together / One More Time / Music Sounds Better with You
# Derezzed
# Safe and Sound (WWW)
# D.A.N.C.E. (WWW)
# Canon x Love S.O.S. (WWW)
# Genesis x Phantom (WWW)
# Pleasure x Newjack x Civilization (WWW)
# Heavy Metal x DVNO (WWW)
# Stress (WWW)
# Love S.O.S. (WWW)
# Alakazam ! x Fire (WWW)
# Waters of Nazareth x We Are your Friends x Phantom 2 (WWW)
# Chorus (WWW)
# Audio, Video, Disco (WWW)
# Stop (WWW)
# Randy (WWW)
# D.A.N.C.E. x Fire x Safe and Sound (WWW)
# Genesis
# Le Freak - Dimitri from Paris Remix; 2018 Remaster
# Lost in Music - Dimitri from Paris Remix [2018 Remaster]
# I Want Your Love - Dimitri from Paris Remix; 2018 Remaster
# Saturday - Dimitri From Paris Remix [2018 Remaster]
# Thinking of You - Dimitri from Paris Remix; 2018 Remaster
# My Forbidden Lover - Dimitri from Paris Remix
# He's the Greatest Dancer - Dimitri from Paris Remix
# I Feel Your Love Comin' On - Dimitri from Paris Remix; 2018 Remaster
# Got to Love Somebody - Dimitri from Paris Remix
# Your Love is Good - Dimitri From Paris Remix; 2018 Remaster
# Le Freak - Dimitri from Paris Instrumental
# Lost in Music - Dimitri from Paris Instrumental [2018 Remaster]
# I Want Your Love - Dimitri from Paris Instrumental; 2018 Remaster
# Saturday - Dimitri From Paris Instrumental [2018 Remaster]
# Thinking of You - Dimitri from Paris Instrumental 2018 Remaster
# My Forbidden Lover - Dimitri from Paris Instrumental
# He's the Greatest Dancer - Dimitri from Paris Instrumental
# I Feel Your Love Comin' On - Dimitri from Paris Instrumental; 2018 Remaster
# Got to Love Somebody - Dimitri from Paris Instrumental
# Your Love Is Good (Dimitri From Paris Instrumental) [2018 Remaster]
# Jacques You Body (Make Me Sweat)
# Dreamin'
# Music Makes You Lose Control
# Soft Machine
# Hypnotise
# (Hey You) What's That Sound?
# Take a Little Time
# From: Disco To: Disco
# Brothers
# About Funk
# Sometimes
# Damaged People
# Jacques Your Body (Make Me Sweat) - Club Mix
# Music Makes You Lose Control - Lrd Remix
# Steps Ahead
# (Hey You) What's That Sound? - Lrd Remix
# Energy
# Sometimes - Junior Sanchez Remix
# Nancy Jamaica
# Jacques Your Body - Cassius Remix Edit
# King Of My Castle - Roy Malone's King Mix
# Idealistic
# The Rockafeller Skank - Remastered Version
# Praise You - Radio Edit
# Brimful of Asha - Norman Cook Remix
# Weapon Of Choice (feat. Bootsy Collins) - Remastered Version
# Gangster Trippin
# I See You Baby - Fatboy Slim Remix
# Wonderful Night - Edit
# Right Here Right Now
# Going Out of My Head
# Sunset (Bird of Prey)
# Everybody Loves a Carnival
# Don't Let the Man Get You Down
# Demons
# Sho Nuff
# Slash Dot Dash
# Santa Cruz
# Champion Sound - Radio Edit
# That Old Pair of Jeans
# Praise You - Ad Rock & Mike D Mix
# Song for Shelter - Chemical Brothers Remix
# Rockafeller Skank - Mulder's Urban Takeover Mix
# Mi Bebe Masoquista - X-Press 2 Remix

# %%
# type(len(my_playlist["items"]))
my_playlist["items"][8]["track"]["name"]
# Out:
# 'One More Time / Aerodynamic'

# %%
results = sp.search(q="One More Time / Aerodynamic", limit = 10)   #?????

# %%
sp.audio_features(results['tracks']['items'][1]['id'])  #   ?????
# Out:
# [{'danceability': 0.298,
#   'energy': 0.0412,
#   'key': 6,
#   'loudness': -29.617,
#   'mode': 0,
#   'speechiness': 0.0397,
#   'acousticness': 0.982,
#   'instrumentalness': 0.868,
#   'liveness': 0.109,
#   'valence': 0.043,
#   'tempo': 106.267,
#   'type': 'audio_features',
#   'id': '7A9tcYw7V9PgAyBrlTfNnO',
#   'uri': 'spotify:track:7A9tcYw7V9PgAyBrlTfNnO',
#   'track_href': 'https://api.spotify.com/v1/tracks/7A9tcYw7V9PgAyBrlTfNnO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7A9tcYw7V9PgAyBrlTfNnO',
#   'duration_ms': 233250,
#   'time_signature': 4}]

# %% [markdown]
# ### Exercise: Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have ot be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Now collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
# Code
