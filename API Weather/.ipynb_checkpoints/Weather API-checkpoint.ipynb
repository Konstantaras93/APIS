# %% [markdown]
# ## First API !

# %%
from pyowm.owm import OWM
from pyowm.utils import config
from pyowm.utils import timestamps

# %%
path = "C:/Users/Kosta/OneDrive/Desktop/Data_Science/5_APIs"

# %%
import sys
sys.path.insert(1, path)

# %%
from api_keys import weather_key

# %%
owm = OWM(weather_key)

mgr = owm.weather_manager()
version_tuple = (major, minor, patch) = owm.version

# %%
observation = mgr.weather_at_place('London,GB')
w = observation.weather

# one_call = mgr.one_call(lat=52.5244, lon=13.4105)
# one_call
w.detailed_status

# Will it be clear tomorrow at this time in Milan (Italy) ?

# forecast = mgr.forecast_at_place('Berlin,DE', 'daily')
# forecast = mgr.forecast_at_place('London,GB', 'daily')
# answer = forecast.will_be_clear_at(timestamps.tomorrow())

# %%
w.detailed_status         # 'clouds'

# %%
w.wind()                  # {'speed': 4.6, 'deg': 330}

# %%
w.humidity                # 87

# %%
w.temperature('celsius')  # {'temp_max': 10.5, 'temp': 9.7, 'temp_min': 9.0}

# %%
w.rain                    # {}

# %%
w.heat_index              # None

# %%
w.clouds                  # 75

# %%
# weather_forecast = []
path = "C:/Users/Kosta/OneDrive/Desktop/Data_Science/6 Recap of Week"
import sys
from pyowm import OWM
from pyowm.utils import config
from pyowm.utils import timestamps
import pandas as pd
sys.path.insert(1, path)
from api_keys import weather_key

OWM_key = weather_key
city = "Ravensburg"  # instead place on a 
country = "DE"

owm = OWM(OWM_key)
mgr = owm.weather_manager()

# Will it be clear tomorrow at this time in Milan (Italy) ?
forecast = mgr.forecast_at_place(city + ',' + country, '3h')
# answer = forecast.will_be_clear_at(timestamps.tomorrow())

from numpy import nan

def forecast_extraction(forecast_object): 
    """
    Given a forecast object from Open weathor Pyhton API, 
    return a structured dataframe. 

    :param: forecast object
    :returns: a dataframe with specific weather information
    """
    forecast_df = pd.json_normalize({
        'time' : forecast_object.reference_time(timeformat='date'), 
        'temperature' : forecast_object.temperature(unit='celsius'), 
        'precipitation_probabily' : forecast_object.precipitation_probability, 
        'rain' : forecast_object.rain, 
        'humidity' : forecast_object.humidity, 
        'status' : forecast_object.status, 
        'snow' : [nan if forecast_object.snow is None else forecast_object.snow], 
        'wind' : forecast_object.wind('km_hour')
    })

    return(forecast_df)

weather_forecast = pd.concat(
    [forecast_extraction(weather) for weather in forecast.forecast.weathers]

)
print("Weather in " + city)
weather_forecast.head(10)
# weather_forecast = [['time','humidity','status','temperature.temp','wind.speed','snow']][:10]
# weather_forecast
# Out:
# Weather in Ravensburg
#                        time  precipitation_probabily  humidity  status  \
# 0 2021-12-08 12:00:00+00:00                     0.99        96    Snow
# 0 2021-12-08 15:00:00+00:00                     1.00        98    Snow
# 0 2021-12-08 18:00:00+00:00                     1.00        99    Snow
# 0 2021-12-08 21:00:00+00:00                     1.00       100    Snow
# 0 2021-12-09 00:00:00+00:00                     1.00       100    Snow
# 0 2021-12-09 03:00:00+00:00                     0.91        99    Snow
# 0 2021-12-09 06:00:00+00:00                     1.00       100    Snow
# 0 2021-12-09 09:00:00+00:00                     0.59       100    Snow
# 0 2021-12-09 12:00:00+00:00                     0.53       100    Snow
# 0 2021-12-09 15:00:00+00:00                     0.33        91  Clouds
#
#              snow  temperature.temp  temperature.temp_kf  \
# 0  [{'3h': 2.27}]              1.66              -272.74
# 0  [{'3h': 2.75}]              1.42              -272.67
# 0  [{'3h': 3.53}]              1.04              -272.84
# 0  [{'3h': 4.02}]              0.78              -273.15
# 0  [{'3h': 1.28}]              0.82              -273.15
# 0  [{'3h': 2.32}]              0.93              -273.15
# 0  [{'3h': 2.04}]              0.74              -273.15
# 0  [{'3h': 0.59}]              1.06              -273.15
# 0  [{'3h': 0.37}]              1.04              -273.15
# 0            [{}]              0.80              -273.15
#
#    temperature.temp_max  temperature.temp_min  temperature.feels_like  \
# 0                  1.66                  1.25                    0.34
# 0                  1.42                  0.94                    1.42
# 0                  1.04                  0.73                    1.04
# 0                  0.78                  0.78                   -0.64
# 0                  0.82                  0.82                    0.82
# 0                  0.93                  0.93                   -1.00
# 0                  0.74                  0.74                   -0.75
# 0                  1.06                  1.06                   -0.56
# 0                  1.04                  1.04                   -1.82
# 0                  0.80                  0.80                   -2.71
#
#    wind.speed  wind.deg  wind.gust  rain.3h
# 0       4.932       170      7.776      NaN
# 0       1.584       302      3.204      NaN
# 0       1.800       292      6.048      NaN
# 0       4.896       309     14.472      NaN
# 0       3.600       226      7.848      NaN
# 0       6.156       278     22.284      NaN
# 0       5.040       262     16.560      NaN
# 0       5.436       233     11.484      NaN
# 0       9.108       253     22.932      NaN
# 0      11.520       247     25.704      NaN

# %% [markdown]
# # TIME FOR TARGET PRACTICE

# %%
weather_forecast = []

# %%
from pyowm import OWM
from pyowm.utils import config
from pyowm.utils import timestamps
import pandas as pd
# import api_keys

cities = ['Berlin','Paris','Amsterdam','Barcelona','Rome','Lisbon','Prague','Vienna','Madrid','London','Zurich']
country = ['DE','FR','NL','ES','IT','PT','CZ','AT','ES','GB','CH']

for city in range(len(cities)):
#     print(cities[i])
#     print(cities[i] + ' ' +country[i])

    owm = weather_key #OWM_key
    mgr = owm.weather_manager()

# for city in cities:

    # Will it be clear tomorrow at this time in Milan (Italy) ?
    forecast = mgr.forecast_at_place(cities[city] + ',' + country[city], '3h')
    # answer = forecast.will_be_clear_at(timestamps.tomorrow())

    from numpy import nan

    def forecast_extraction(forecast_object): 
        """
        Given a forecast object from Open weathor Pyhton API, 
        return a structured dataframe. 

        :param: forecast object
        :returns: a dataframe with specific weather information
        """
        forecast_df = pd.json_normalize({
            'country' : f"{country[city]}",
            'city' : f"{cities[city]}",
            'time' : forecast_object.reference_time(timeformat='date'), 
            'temperature' : forecast_object.temperature(unit='celsius'), 
            'precipitation_probabily' : forecast_object.precipitation_probability, 
            'rain' : forecast_object.rain, 
            'humidity' : forecast_object.humidity, 
            'status' : forecast_object.status, 
            'snow' : [nan if forecast_object.snow is None else forecast_object.snow], 
            'wind' : forecast_object.wind('km_hour')
        })
    
        return(forecast_df)

    weather_forecast = pd.concat(
        [forecast_extraction(weather) for weather in forecast.forecast.weathers]
    )
    
    weather_forecast.head()

# %%
weather_forecast.head()
